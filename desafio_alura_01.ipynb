# %% [markdown]
# <a href="https://colab.research.google.com/github/szjunior/desafio_allura/blob/main/desafio_alura_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import glob

# Passo 2: Listar os arquivos CSV na pasta local
file_path = '/content/drive/MyDrive/desafio_alura/dia_01/*.csv'
csv_files = glob.glob(file_path)

# Lista para armazenar cada DataFrame individual
dataframes = []

# Passo 3 e 4: Ler cada arquivo CSV e adicionar à lista de DataFrames
for file in csv_files:
    df = pd.read_csv(file)
    dataframes.append(df)

# Passo 5: Concatenar todos os DataFrames em um único DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# Exibir o DataFrame combinado
print(combined_df)
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709684       L095049                            NaN
# ...                ...           ...                            ...
# 2258013        2989086    2008047044                            NaN
# 2258014        2989087    2008047047                            NaN
# 2258015        2989088    2010052905                            NaN
# 2258016        2989089    2010048023                            NaN
# 2258017        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
# Passo 1: Eliminar as linhas com dados nulos
df_sem_nulos = combined_df.dropna()

# Passo 2: Remover as linhas duplicadas
emprestimos_df = df_sem_nulos.drop_duplicates()

# Exibir o DataFrame final
print(emprestimos_df)
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 8               709688    2007027500  2010/01/19 15:59:26.464000000
# 9               709689       L157395  2010/01/19 15:59:26.447000000
# 11              709691    2008046357  2010/01/19 11:50:13.404000000
# ...                ...           ...                            ...
# 2257925        2988998    2010084076  2020/04/27 23:27:14.132000000
# 2257926        2988999    2011024982  2020/04/27 23:27:14.108000000
# 2257934        2989007    2014069838  2020/03/23 10:42:38.432000000
# 2257967        2989040    2016025770  2020/04/01 22:25:43.652000000
# 2257991        2989064       S023116  2021/07/19 16:17:24.750000000
#
#                        data_emprestimo                 data_devolucao  \
# 2        2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# ...

# %%
emprestimos_df.head()
# Out:
#     id_emprestimo codigo_barras                 data_renovacao  \
# 2          709686    2006017618  2010/01/26 08:07:01.738000000
# 3          709687       L184117  2010/01/18 11:07:46.470000000
# 8          709688    2007027500  2010/01/19 15:59:26.464000000
# 9          709689       L157395  2010/01/19 15:59:26.447000000
# 11         709691    2008046357  2010/01/19 11:50:13.404000000
#
#                   data_emprestimo                 data_devolucao  \
# 2   2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3   2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 8   2010/01/04 08:27:33.569000000  2010/02/03 13:06:30.662000000
# 9   2010/01/04 08:27:33.596000000  2010/02/03 13:06:43.125000000
# 11  2010/01/04 09:02:30.576000000  2010/02/02 12:13:36.132000000
#
#     matricula_ou_siape    tipo_vinculo_usuario
# 2         2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO
# 3         2.007211e+08      ALUNO DE GRADUAÇÃO
# 8         2.009046e+09      ALUNO DE GRADUAÇÃO
# ...

# %%
import pandas as pd

# URL do arquivo Parquet
url = "https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet"

# Ler o arquivo Parquet diretamente da URL
exemplares_df = pd.read_parquet(url, engine='pyarrow')

# Exibir o DataFrame
exemplares_df.head()
# Out:
#        id_exemplar codigo_barras            colecao  \
# index
# 0                5       L000003  Acervo Circulante
# 1                4       L000002  Acervo Circulante
# 2                3       L000001  Acervo Circulante
# 3                7       L000114  Acervo Circulante
# 5               10       L000041  Acervo Circulante
#
#                            biblioteca status_material  localizacao  \
# index
# 0      Biblioteca Central Zila Mamede         REGULAR          694
# 1      Biblioteca Central Zila Mamede         REGULAR          688
# 2      Biblioteca Central Zila Mamede        ESPECIAL          638
# 3      Biblioteca Central Zila Mamede         REGULAR          616
# 5      Biblioteca Central Zila Mamede        ESPECIAL          657
#
#        registro_sistema
# index
# 0                     1
# 1                     1
# 2                     1
# 3                     5
# 5                    15

# %%
import pandas as pd

# URL do arquivo Parquet
url = "https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet"

# Ler o arquivo Parquet diretamente da URL
exemplares_df = pd.read_parquet(url, engine='pyarrow')

# Eliminar as linhas com dados nulos
exemplares_sem_nulos = exemplares_df.dropna()

# Remover as linhas duplicadas
exemplares_final = exemplares_sem_nulos.drop_duplicates()

# Exibir o DataFrame final
print(exemplares_final)
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %%
exemplares_final.head()
# Out:
#        id_exemplar codigo_barras            colecao  \
# index
# 0                5       L000003  Acervo Circulante
# 1                4       L000002  Acervo Circulante
# 2                3       L000001  Acervo Circulante
# 3                7       L000114  Acervo Circulante
# 5               10       L000041  Acervo Circulante
#
#                            biblioteca status_material  localizacao  \
# index
# 0      Biblioteca Central Zila Mamede         REGULAR          694
# 1      Biblioteca Central Zila Mamede         REGULAR          688
# 2      Biblioteca Central Zila Mamede        ESPECIAL          638
# 3      Biblioteca Central Zila Mamede         REGULAR          616
# 5      Biblioteca Central Zila Mamede        ESPECIAL          657
#
#        registro_sistema
# index
# 0                     1
# 1                     1
# 2                     1
# 3                     5
# 5                    15

# %%
import pandas as pd

# Exemplo de criação dos DataFrames para ilustração (remova esta parte se já tem os DataFrames prontos)
# emprestimos_df = combined_df.copy()  # Supondo que combined_df é o emprestimos_df
# exemplares_df = exemplares_final.copy()  # Supondo que exemplares_final é o exemplares_df

# Mesclar os DataFrames através do campo codigo_barras
dados_acervo = pd.merge(
    emprestimos_df,
    exemplares_final,
    on='codigo_barras',
    how='inner'
)

# Exibir o DataFrame mesclado
print(dados_acervo)
# Out:
#         id_emprestimo codigo_barras                 data_renovacao  \
# 0              709686    2006017618  2010/01/26 08:07:01.738000000
# 1              749227    2006017618  2010/04/19 17:35:25.987000000
# 2             1175444    2006017618  2012/03/11 17:05:30.982000000
# 3             1209694    2006017618  2012/04/11 12:34:59.458000000
# 4             1374962    2006017618  2012/12/12 07:40:40.406000000
# ...               ...           ...                            ...
# 906407        2988812    2016019436  2020/04/26 11:43:40.062000000
# 906408        2988874    2010080699  2021/08/10 02:30:14.871000000
# 906409        2988922    2018031109  2020/03/29 10:17:16.672000000
# 906410        2988968    2016033194  2020/04/06 18:21:57.168000000
# 906411        2989007    2014069838  2020/03/23 10:42:38.432000000
#
#                       data_emprestimo                 data_devolucao  \
# 0       2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# ...

# %%
dados_acervo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709686    2006017618  2010/01/26 08:07:01.738000000
# 1         749227    2006017618  2010/04/19 17:35:25.987000000
# 2        1175444    2006017618  2012/03/11 17:05:30.982000000
# 3        1209694    2006017618  2012/04/11 12:34:59.458000000
# 4        1374962    2006017618  2012/12/12 07:40:40.406000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 1  2010/04/05 11:25:57.627000000  2010/04/27 11:37:02.530000000
# 2  2012/02/24 16:18:40.959000000  2012/03/28 14:32:13.000000000
# 3  2012/03/28 14:33:04.249000000  2012/04/25 11:48:28.000000000
# 4  2012/11/14 12:41:25.081000000  2013/01/15 17:10:17.000000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO       195347  Acervo Circulante
# ...

# %%
dados_acervo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 906412 entries, 0 to 906411
# Data columns (total 13 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id_emprestimo         906412 non-null  int64
#  1   codigo_barras         906412 non-null  object
#  2   data_renovacao        906412 non-null  object
#  3   data_emprestimo       906412 non-null  object
#  4   data_devolucao        906412 non-null  object
#  5   matricula_ou_siape    906412 non-null  float64
#  6   tipo_vinculo_usuario  906412 non-null  object
#  7   id_exemplar           906412 non-null  int64
#  8   colecao               906412 non-null  object
#  9   biblioteca            906412 non-null  object
#  10  status_material       906412 non-null  object
#  11  localizacao           906412 non-null  int64
#  12  registro_sistema      906412 non-null  int64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 89.9+ MB

# %%
# Excluir a coluna 'registro_sistema'
dados_acervo = dados_acervo.drop(columns=['registro_sistema'])

# Exibir o DataFrame resultante
print(dados_acervo)
# Out:
#         id_emprestimo codigo_barras                 data_renovacao  \
# 0              709686    2006017618  2010/01/26 08:07:01.738000000
# 1              749227    2006017618  2010/04/19 17:35:25.987000000
# 2             1175444    2006017618  2012/03/11 17:05:30.982000000
# 3             1209694    2006017618  2012/04/11 12:34:59.458000000
# 4             1374962    2006017618  2012/12/12 07:40:40.406000000
# ...               ...           ...                            ...
# 906407        2988812    2016019436  2020/04/26 11:43:40.062000000
# 906408        2988874    2010080699  2021/08/10 02:30:14.871000000
# 906409        2988922    2018031109  2020/03/29 10:17:16.672000000
# 906410        2988968    2016033194  2020/04/06 18:21:57.168000000
# 906411        2989007    2014069838  2020/03/23 10:42:38.432000000
#
#                       data_emprestimo                 data_devolucao  \
# 0       2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# ...

# %%
dados_acervo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709686    2006017618  2010/01/26 08:07:01.738000000
# 1         749227    2006017618  2010/04/19 17:35:25.987000000
# 2        1175444    2006017618  2012/03/11 17:05:30.982000000
# 3        1209694    2006017618  2012/04/11 12:34:59.458000000
# 4        1374962    2006017618  2012/12/12 07:40:40.406000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 1  2010/04/05 11:25:57.627000000  2010/04/27 11:37:02.530000000
# 2  2012/02/24 16:18:40.959000000  2012/03/28 14:32:13.000000000
# 3  2012/03/28 14:33:04.249000000  2012/04/25 11:48:28.000000000
# 4  2012/11/14 12:41:25.081000000  2013/01/15 17:10:17.000000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO       195347  Acervo Circulante
# ...

# %%
# Transformar a coluna 'matricula_ou_siape' em formato string
dados_acervo['matricula_ou_siape'] = dados_acervo['matricula_ou_siape'].astype(str)

# %%
dados_acervo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709686    2006017618  2010/01/26 08:07:01.738000000
# 1         749227    2006017618  2010/04/19 17:35:25.987000000
# 2        1175444    2006017618  2012/03/11 17:05:30.982000000
# 3        1209694    2006017618  2012/04/11 12:34:59.458000000
# 4        1374962    2006017618  2012/12/12 07:40:40.406000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 1  2010/04/05 11:25:57.627000000  2010/04/27 11:37:02.530000000
# 2  2012/02/24 16:18:40.959000000  2012/03/28 14:32:13.000000000
# 3  2012/03/28 14:33:04.249000000  2012/04/25 11:48:28.000000000
# 4  2012/11/14 12:41:25.081000000  2013/01/15 17:10:17.000000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008112114.0  ALUNO DE PÓS-GRADUAÇÃO       195347  Acervo Circulante
# ...

# %%
import pandas as pd

# Supondo que o DataFrame dados_acervo já esteja carregado

# Lista de tuplas com os intervalos e suas descrições
intervalos = [
    (0, 99, 'Generalidades. Ciência e conhecimento.'),
    (100, 199, 'Filosofia e psicologia.'),
    (200, 299, 'Religião.'),
    (300, 399, 'Ciências sociais.'),
    (400, 499, 'Classe vaga. Provisoriamente não ocupada.'),
    (500, 599, 'Matemática e ciências naturais.'),
    (600, 699, 'Ciências aplicadas.'),
    (700, 799, 'Belas artes.'),
    (800, 899, 'Linguagem. Língua. Linguística.'),
    (900, 999, 'Geografia. Biografia. História.')
]

# Definir a função para mapear os valores de localizacao para as descrições fornecidas
def mapear_localizacao(localizacao):
    for inicio, fim, descricao in intervalos:
        if inicio <= localizacao <= fim:
            return descricao
    return 'Desconhecido'

# Aplicar a função ao DataFrame para criar a nova coluna
dados_acervo['descricao_localizacao'] = dados_acervo['localizacao'].apply(mapear_localizacao)

# Exibir o DataFrame resultante
print(dados_acervo)
# Out:
#         id_emprestimo codigo_barras                 data_renovacao  \
# 0              709686    2006017618  2010/01/26 08:07:01.738000000
# 1              749227    2006017618  2010/04/19 17:35:25.987000000
# 2             1175444    2006017618  2012/03/11 17:05:30.982000000
# 3             1209694    2006017618  2012/04/11 12:34:59.458000000
# 4             1374962    2006017618  2012/12/12 07:40:40.406000000
# ...               ...           ...                            ...
# 906407        2988812    2016019436  2020/04/26 11:43:40.062000000
# 906408        2988874    2010080699  2021/08/10 02:30:14.871000000
# 906409        2988922    2018031109  2020/03/29 10:17:16.672000000
# 906410        2988968    2016033194  2020/04/06 18:21:57.168000000
# 906411        2989007    2014069838  2020/03/23 10:42:38.432000000
#
#                       data_emprestimo                 data_devolucao  \
# 0       2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# ...

# %%
dados_acervo.head(-340)
# Out:
#         id_emprestimo codigo_barras                 data_renovacao  \
# 0              709686    2006017618  2010/01/26 08:07:01.738000000
# 1              749227    2006017618  2010/04/19 17:35:25.987000000
# 2             1175444    2006017618  2012/03/11 17:05:30.982000000
# 3             1209694    2006017618  2012/04/11 12:34:59.458000000
# 4             1374962    2006017618  2012/12/12 07:40:40.406000000
# ...               ...           ...                            ...
# 906067        2972472    2010083655  2020/03/05 16:36:58.246000000
# 906068        2972527    2018004201  2020/03/05 23:09:13.884000000
# 906069        2972560    2017022396  2020/03/06 00:27:28.518000000
# 906070        2972571    2014095541  2020/03/09 07:29:27.533000000
# 906071        2972573    2014041581  2020/03/09 07:29:27.495000000
#
#                       data_emprestimo                 data_devolucao  \
# 0       2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# ...
